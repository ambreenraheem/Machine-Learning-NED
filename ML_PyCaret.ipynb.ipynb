# %% [markdown]
# ### Name: Ambreen Abdul Raheem
# ### Teacher: Sir Sajid Majeed
# ### Subject: Machine Learning
# ### Program: Data Science with Artificial Intelligence
# ### University: NED Academy
# ### Github:https://github.com/ambreenraheem?tab=overview&from=2024-09-01&to=2024-09-30
# ### Email: ambreen.a.raheem@outlook.com
# ### LinkedIn: https://www.linkedin.com/in/ambreen-abdul-raheem-122509300/

# %%
# %pip install pycaret
from pycaret.utils import version
version()
# Out:
# ...
# '3.3.2'

# %% [markdown]
# # 1. Getting Dataset from PyCaret's Library.

# %%
from pycaret.datasets import get_data
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
index.isnull().sum()
# Out:
# Dataset               0
# Data Types            0
# Default Task          0
# Target Variable 1    14
# Target Variable 2    53
# # Instances           0
# # Attributes          0
# Missing Values        0
# dtype: int64

# %%
data1 = get_data('juice')
# data = get_data('traffic')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_20.groupby('Store7').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_19.groupby('Purchase').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_15['Id'].plot(kind='hist', bins=20, title='Id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data1.shape
# Out:
# (1070, 19)

# %%
data1.isnull().sum()
# Out:
# Id                0
# Purchase          0
# WeekofPurchase    0
# StoreID           0
# PriceCH           0
# PriceMM           0
# DiscCH            0
# DiscMM            0
# SpecialCH         0
# SpecialMM         0
# LoyalCH           0
# SalePriceMM       0
# SalePriceCH       0
# PriceDiff         0
# Store7            0
# PctDiscMM         0
# PctDiscCH         0
# ListPriceDiff     0
# STORE             0
# dtype: int64

# %%
data1.columns
# Out:
# Index(['Id', 'Purchase', 'WeekofPurchase', 'StoreID', 'PriceCH', 'PriceMM',
#        'DiscCH', 'DiscMM', 'SpecialCH', 'SpecialMM', 'LoyalCH', 'SalePriceMM',
#        'SalePriceCH', 'PriceDiff', 'Store7', 'PctDiscMM', 'PctDiscCH',
#        'ListPriceDiff', 'STORE'],
#       dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              1070 non-null   int64
#  1   Purchase        1070 non-null   object
#  2   WeekofPurchase  1070 non-null   int64
#  3   StoreID         1070 non-null   int64
#  4   PriceCH         1070 non-null   float64
#  5   PriceMM         1070 non-null   float64
#  6   DiscCH          1070 non-null   float64
#  7   DiscMM          1070 non-null   float64
#  8   SpecialCH       1070 non-null   int64
#  9   SpecialMM       1070 non-null   int64
#  10  LoyalCH         1070 non-null   float64
#  11  SalePriceMM     1070 non-null   float64
#  12  SalePriceCH     1070 non-null   float64
#  13  PriceDiff       1070 non-null   float64
#  14  Store7          1070 non-null   object
#  15  PctDiscMM       1070 non-null   float64
#  16  PctDiscCH       1070 non-null   float64
# ...

# %% [markdown]
# # 2. Initialize Setup

# %%
from pycaret.classification import *
clf1 = setup(data1, target = 'Purchase', session_id=123, log_experiment=False, experiment_name='juice1')
# Out:
# <style type="text/css">
# #T_bbaf9_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bbaf9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbaf9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bbaf9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbaf9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbaf9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bbaf9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bbaf9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bbaf9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bbaf9_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_bbaf9_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Compare Best Model

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_fd70f th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # 3.Create Model

# %% [markdown]
# 1. Linear Regression (lr)

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_670a2_row10_col0, #T_670a2_row10_col1, #T_670a2_row10_col2, #T_670a2_row10_col3, #T_670a2_row10_col4, #T_670a2_row10_col5, #T_670a2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_670a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_670a2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_670a2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_670a2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_670a2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_670a2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_670a2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_670a2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# 2. Decision Tree Classifier (dt)

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_1a609_row10_col0, #T_1a609_row10_col1, #T_1a609_row10_col2, #T_1a609_row10_col3, #T_1a609_row10_col4, #T_1a609_row10_col5, #T_1a609_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1a609" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a609_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1a609_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1a609_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1a609_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1a609_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1a609_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1a609_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# 3. Random Forest Classifier (rf)

# %%
rf = create_model('rf', fold = 5)
# Out:
# <style type="text/css">
# #T_2ccf6_row5_col0, #T_2ccf6_row5_col1, #T_2ccf6_row5_col2, #T_2ccf6_row5_col3, #T_2ccf6_row5_col4, #T_2ccf6_row5_col5, #T_2ccf6_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2ccf6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ccf6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2ccf6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2ccf6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2ccf6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2ccf6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2ccf6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2ccf6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# 4. Linear Discriminant Analysis

# %%
lda = create_model('lda')
# Out:
# <style type="text/css">
# #T_50e92_row10_col0, #T_50e92_row10_col1, #T_50e92_row10_col2, #T_50e92_row10_col3, #T_50e92_row10_col4, #T_50e92_row10_col5, #T_50e92_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_50e92" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50e92_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_50e92_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_50e92_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_50e92_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_50e92_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_50e92_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_50e92_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_38.groupby('Turbo').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
models(type='ensemble').index.tolist()
# Out:
# ['rf', 'ada', 'gbc', 'et', 'xgboost', 'lightgbm']

# %%
ensembled_models = compare_models(include = models(type='ensemble').index.tolist(), fold = 3)
# Out:
# <style type="text/css">
# #T_43bb0 th {
#   text-align: left;
# }
# #T_43bb0_row0_col0, #T_43bb0_row1_col0, #T_43bb0_row1_col1, #T_43bb0_row1_col2, #T_43bb0_row1_col3, #T_43bb0_row1_col4, #T_43bb0_row1_col5, #T_43bb0_row1_col6, #T_43bb0_row1_col7, #T_43bb0_row2_col0, #T_43bb0_row2_col1, #T_43bb0_row2_col2, #T_43bb0_row2_col3, #T_43bb0_row2_col4, #T_43bb0_row2_col5, #T_43bb0_row2_col6, #T_43bb0_row2_col7, #T_43bb0_row3_col0, #T_43bb0_row3_col1, #T_43bb0_row3_col2, #T_43bb0_row3_col3, #T_43bb0_row3_col4, #T_43bb0_row3_col5, #T_43bb0_row3_col6, #T_43bb0_row3_col7, #T_43bb0_row4_col0, #T_43bb0_row4_col1, #T_43bb0_row4_col2, #T_43bb0_row4_col3, #T_43bb0_row4_col4, #T_43bb0_row4_col5, #T_43bb0_row4_col6, #T_43bb0_row4_col7, #T_43bb0_row5_col0, #T_43bb0_row5_col1, #T_43bb0_row5_col2, #T_43bb0_row5_col3, #T_43bb0_row5_col4, #T_43bb0_row5_col5, #T_43bb0_row5_col6, #T_43bb0_row5_col7 {
#   text-align: left;
# }
# ...

# %% [markdown]
# # 5. Tune Hyperparameters

# %% [markdown]
# Tuned Linear Regression

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_e9bab_row10_col0, #T_e9bab_row10_col1, #T_e9bab_row10_col2, #T_e9bab_row10_col3, #T_e9bab_row10_col4, #T_e9bab_row10_col5, #T_e9bab_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e9bab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9bab_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e9bab_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e9bab_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e9bab_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e9bab_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e9bab_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e9bab_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# Tuned Random Forest Classifier

# %%
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_42cdd_row10_col0, #T_42cdd_row10_col1, #T_42cdd_row10_col2, #T_42cdd_row10_col3, #T_42cdd_row10_col4, #T_42cdd_row10_col5, #T_42cdd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_42cdd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42cdd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_42cdd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_42cdd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_42cdd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_42cdd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_42cdd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_42cdd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# # 6. Ensemble Model

# %% [markdown]
#  Ensemble Decision Tree Classifier

# %%
bagged_dt = ensemble_model(dt)
# Out:
# <style type="text/css">
# #T_a1382_row10_col0, #T_a1382_row10_col1, #T_a1382_row10_col2, #T_a1382_row10_col3, #T_a1382_row10_col4, #T_a1382_row10_col5, #T_a1382_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a1382" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1382_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a1382_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a1382_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a1382_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a1382_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a1382_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a1382_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
boosted_dt = ensemble_model(dt, method = 'Boosting')
# Out:
# <style type="text/css">
# #T_99383_row10_col0, #T_99383_row10_col1, #T_99383_row10_col2, #T_99383_row10_col3, #T_99383_row10_col4, #T_99383_row10_col5, #T_99383_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_99383" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99383_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_99383_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_99383_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_99383_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_99383_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_99383_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_99383_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# # 7. Blend Models
# We can blend different models with each other.

# %%
blender = blend_models(estimator_list = [boosted_dt, bagged_dt, tuned_rf], method = 'soft')
# Out:
# <style type="text/css">
# #T_4695d_row10_col0, #T_4695d_row10_col1, #T_4695d_row10_col2, #T_4695d_row10_col3, #T_4695d_row10_col4, #T_4695d_row10_col5, #T_4695d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4695d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4695d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4695d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4695d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4695d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4695d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4695d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4695d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# # 8. Stack Models
#  We can Stack different models with each other

# %%
stacker = stack_models(estimator_list = [boosted_dt,bagged_dt,tuned_rf], meta_model=rf)
# Out:
# <style type="text/css">
# #T_1b1e7_row10_col0, #T_1b1e7_row10_col1, #T_1b1e7_row10_col2, #T_1b1e7_row10_col3, #T_1b1e7_row10_col4, #T_1b1e7_row10_col5, #T_1b1e7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1b1e7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b1e7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1b1e7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1b1e7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1b1e7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1b1e7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1b1e7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1b1e7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# # 9. Analyze Model
# Analyzing Models by plotting

# %%
plot_model(rf)

# %%
plot_model(rf, plot = 'confusion_matrix')

# %%
plot_model(rf, plot = 'feature')

# %%
plot_model(rf, plot = 'boundary')

# %%
plot_model(rf, plot = 'pr')

# %%
plot_model(rf, plot = 'class_report')

# %% [markdown]
# Evaluating models

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # 10. Interpret Model

# %%
lightgbm = create_model('lightgbm', cross_validation=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_41faa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41faa_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_41faa_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_41faa_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_41faa_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_41faa_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_41faa_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_41faa_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41faa_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_41faa_row0_col0" class="data row0 col0" >0.8224</td>
#       <td id="T_41faa_row0_col1" class="data row0 col1" >0.8878</td>
# ...

# %%
interpret_model(lightgbm)

# %% [markdown]
# # 11. AutoML()

# %%
best = automl(optimize = 'Recall')
best
# Out:
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %% [markdown]
# # 12. Predict Model

# %%
pred_holdouts = predict_model(lr)
pred_holdouts.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_25496" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25496_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_25496_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_25496_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_25496_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_25496_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_25496_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_25496_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_25496_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25496_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# with new variable we can predict our data once again

# %%
new_data = data1.copy()
new_data.drop(['Purchase'], axis=1, inplace=True)
predict_new = predict_model(best, data=new_data)
predict_new.head()
# Out:
#    Id  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  SpecialCH  \
# 0   1             237        1     1.75     1.99    0.00     0.0          0
# 1   2             239        1     1.75     1.99    0.00     0.3          0
# 2   3             245        1     1.86     2.09    0.17     0.0          0
# 3   4             227        1     1.69     1.69    0.00     0.0          0
# 4   5             228        7     1.69     1.69    0.00     0.0          0
#
#    SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  PctDiscMM  \
# 0          0  0.500000         1.99         1.75       0.24     No   0.000000
# 1          1  0.600000         1.69         1.75      -0.06     No   0.150754
# 2          0  0.680000         2.09         1.69       0.40     No   0.000000
# 3          0  0.400000         1.69         1.69       0.00     No   0.000000
# 4          0  0.956535         1.69         1.69       0.00    Yes   0.000000
#
# ...

# %% [markdown]
# # 13. Save / Load Model

# %%
save_model(best_model, model_name='Linear Discriminant Analysis')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Id', 'WeekofPurchase', 'StoreID',
#                                               'PriceCH', 'PriceMM', 'DiscCH',
#                                               'DiscMM', 'SpecialCH', 'SpecialMM',
#                                               'LoyalCH', 'SalePriceMM',
#                                               'SalePriceCH', 'PriceDi...
#                                                                 drop_invariant=False,
#                                                                 handle_missing='return_nan',
# ...

# %%
# loaded_bestmodel = load_model(best_model, model_name='Linear Discriminant Analysis')
# print(loaded_bestmodel)
